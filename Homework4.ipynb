# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('img',dst)
cv2.imshow('simg',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[582,529],[576,335],[752,374],[763,535]])
pts2 = np.float32([[582,529],[582,335],[752,335],[752,529]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('img',dst)
cv2.imshow('simg',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
